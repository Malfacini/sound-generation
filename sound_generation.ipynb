# %% [markdown]
# Final Project
# Class: E-89 Deep Learning, Fall 2025
# Student: Doug Malfacini
#
# Title: Sound Geneartion - Restoring Damaged Sound

# %%
import tensorflow_datasets as tfds

DATA_DIR = "~/tfds_data"  # where it will cache/download

builder = tfds.builder("maestro", data_dir=DATA_DIR)  # MAESTRO dataset
builder.download_and_prepare()  # downloads + extracts + builds TFDS files

ds_train = builder.as_dataset(split="train", shuffle_files=True)
ds_valid = builder.as_dataset(split="validation")
ds_test  = builder.as_dataset(split="test")

# example: look at one record
ex = next(iter(ds_train.take(1)))
print(ex.keys())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/8l/246_74ln65jb38p5lpngwg3w0000gp/T/ipykernel_14578/2610019302.py in <cell line: 0>()
# ----> 1 import tensorflow_datasets as tfds
#       2
#       3 DATA_DIR = "~/tfds_data"  # where it will cache/download
#       4
#       5 builder = tfds.builder("maestro", data_dir=DATA_DIR)  # MAESTRO dataset
#
# ModuleNotFoundError: No module named 'tensorflow_datasets'
